# %%
# Install Important Libraries    
import os
import numpy as np 
import matplotlib.pyplot as plt
import tensorflow as tf 
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D, Flatten, Dense, Dropout
MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# %%
# Define Dataset path
dataset_path = r"C:\Users\HP\Downloads\PRAICP-1001-GenderDetc\Data\gender_dataset_face"

# %%
# Data Augmentation and Preprocessing 
datagen = ImageDataGenerator(rescale=1/255, validation_split=0.1)

# %%
# Load Traning data
train_data = datagen.flow_from_directory(dataset_path,target_size=(128,128),batch_size=32,class_mode='binary',
                                        subset='training')
# Out:
# Found 2077 images belonging to 2 classes.

# %%
# Load Validation data 
val_data = datagen.flow_from_directory(dataset_path,target_size=(128,128),batch_size=32,class_mode='binary',
                                      subset='validation')
# Out:
# Found 230 images belonging to 2 classes.

# %%
print(train_data.class_indices)
# Out:
# {'man': 0, 'woman': 1}

# %%
# Build the CNN model
model = Sequential([Conv2D(32,(3,3), activation='relu',input_shape=(128,128,3)),MaxPooling2D(2,2),
                    Conv2D(64,(3,3), activation='relu'),MaxPooling2D(2,2),
                    Conv2D(128,(3,3), activation='relu'),MaxPooling2D(2,2),
                    Flatten(),Dense(128, activation='relu'),Dropout(0.5),Dense(1,activation='sigmoid')])

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001),loss='binary_crossentropy',metrics=['accuracy'])

# %%
# Model Summary
print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 126, 126, 32)      896
#
#  max_pooling2d_6 (MaxPoolin  (None, 63, 63, 32)        0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 61, 61, 64)        18496
#
#  max_pooling2d_7 (MaxPoolin  (None, 30, 30, 64)        0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 128)       73856
#
#  max_pooling2d_8 (MaxPoolin  (None, 14, 14, 128)       0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 25088)             0
#
#  dense_4 (Dense)             (None, 128)               3211392
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 3304769 (12.61 MB)
# Trainable params: 3304769 (12.61 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
# Train the model
history = model.fit(train_data,validation_data = val_data,epochs = 10)
# Out:
# Epoch 1/10
# 65/65 [==============================] - 24s 347ms/step - loss: 0.6824 - accuracy: 0.5696 - val_loss: 0.4110 - val_accuracy: 0.8435
# Epoch 2/10
# 65/65 [==============================] - 22s 333ms/step - loss: 0.4612 - accuracy: 0.7853 - val_loss: 0.3485 - val_accuracy: 0.8522
# Epoch 3/10
# 65/65 [==============================] - 22s 334ms/step - loss: 0.3242 - accuracy: 0.8647 - val_loss: 0.3306 - val_accuracy: 0.8522
# Epoch 4/10
# 65/65 [==============================] - 22s 340ms/step - loss: 0.2810 - accuracy: 0.8878 - val_loss: 0.3312 - val_accuracy: 0.9000
# Epoch 5/10
# 65/65 [==============================] - 22s 336ms/step - loss: 0.2468 - accuracy: 0.9018 - val_loss: 0.3129 - val_accuracy: 0.8826
# Epoch 6/10
# 65/65 [==============================] - 22s 333ms/step - loss: 0.2315 - accuracy: 0.9085 - val_loss: 0.2841 - val_accuracy: 0.8870
# Epoch 7/10
# 65/65 [==============================] - 22s 331ms/step - loss: 0.1853 - accuracy: 0.9191 - val_loss: 0.2880 - val_accuracy: 0.8652
# Epoch 8/10
# 65/65 [==============================] - 22s 333ms/step - loss: 0.1723 - accuracy: 0.9283 - val_loss: 0.2735 - val_accuracy: 0.8783
# Epoch 9/10
# 65/65 [==============================] - 22s 333ms/step - loss: 0.1490 - accuracy: 0.9364 - val_loss: 0.2136 - val_accuracy: 0.8957
# Epoch 10/10
# 65/65 [==============================] - 22s 343ms/step - loss: 0.1501 - accuracy: 0.9437 - val_loss: 0.2937 - val_accuracy: 0.8957

# %%
# Evaluate on Validation data
val_loss, val_accuracy = model.evaluate(val_data)
print(f"Validation Accuracy: {accuracy * 100:2f}%")
# Out:
# 8/8 [==============================] - 1s 92ms/step - loss: 0.2937 - accuracy: 0.8957
# Validation Accuracy: 93.043476%

# %%
train_loss, train_accuracy = model.evaluate(train_data)
print(f"Training Accuracy: {train_accuracy * 100:.2f}%")
# Out:
# 65/65 [==============================] - 8s 120ms/step - loss: 0.0794 - accuracy: 0.9697
# Training Accuracy: 96.97%

# %%
# Save the trained model
model.save(r"C:\Users\HP\Downloads\PRAICP-1001-GenderDetc\gender_detection_model")
# Out:
# INFO:tensorflow:Assets written to: C:\Users\HP\Downloads\PRAICP-1001-GenderDetc\gender_detection_model\assets
# INFO:tensorflow:Assets written to: C:\Users\HP\Downloads\PRAICP-1001-GenderDetc\gender_detection_model\assets

# %%
# Load the saved model
model = tf.keras.models.load_model(r"C:\Users\HP\Downloads\PRAICP-1001-GenderDetc\gender_detection_model")

# %%
# Test with a new image
from tensorflow.keras.preprocessing import image
def predict_gender(img_path): 
    img = image.load_img(img_path, target_size=(128,128))
    img_array = image.img_to_array(img) / 255
    img_array = np.expand_dims(img_array,axis=0) 
    
    prediction = model.predict(img_array)
    return "Male" if prediction[0][0] < 0.5 else "Female" 


test_image_path = (r"C:\Users\HP\Downloads\PRAICP-1001-GenderDetc\Data\gender_dataset_face\man\face_1516.jpg")
print(predict_gender(test_image_path))
# Out:
# 1/1 [==============================] - 0s 90ms/step
# Male

# %%
test_image_path = (r"C:\Users\HP\Downloads\girly.jpeg")
print(predict_gender(test_image_path))
# Out:
# 1/1 [==============================] - 0s 30ms/step
# Female
